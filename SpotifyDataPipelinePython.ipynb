# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd

# %%
client_credentials_manager = SpotifyClientCredentials(client_id="client credentials", client_secret="client secret")

# %%
sp = spotipy.Spotify(client_credentials_manager = client_credentials_manager)

# %%
playlist_link = "https://open.spotify.com/playlist/5TZkls9cEOzWDR6qCxwDot"

# %%
sp.playlist_tracks(playlist_URI)
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/5TZkls9cEOzWDR6qCxwDot/tracks?offset=0&limit=100&additional_types=track',
#  'items': [{'added_at': '2024-05-06T18:25:48Z',
#    'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/theswingingturtle'},
#     'href': 'https://api.spotify.com/v1/users/theswingingturtle',
#     'id': 'theswingingturtle',
#     'type': 'user',
#     'uri': 'spotify:user:theswingingturtle'},
#    'is_local': False,
#    'primary_color': None,
#    'track': {'preview_url': None,
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
#      'HN',
#      'HK',
#      'HU',
#      'IS',
#      'IE',
#      'IT',
#      'LV',
#      'LT',
#      'LU',
#      'MY',
#      'MT',
# ...

# %%
data = sp.playlist_tracks(playlist_URI)

# %%
data['items'][0]
# Out:
# {'added_at': '2024-05-06T18:25:48Z',
#  'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/theswingingturtle'},
#   'href': 'https://api.spotify.com/v1/users/theswingingturtle',
#   'id': 'theswingingturtle',
#   'type': 'user',
#   'uri': 'spotify:user:theswingingturtle'},
#  'is_local': False,
#  'primary_color': None,
#  'track': {'preview_url': None,
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'SE',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
# ...

# %%
data['items'][0]['track']
# Out:
# {'preview_url': None,
#  'available_markets': ['AR',
#   'AU',
#   'AT',
#   'BE',
#   'BO',
#   'BR',
#   'BG',
#   'CA',
#   'CL',
#   'CO',
#   'CR',
#   'CY',
#   'CZ',
#   'DK',
#   'DO',
#   'DE',
#   'EC',
#   'EE',
#   'SV',
#   'FI',
#   'FR',
#   'GR',
#   'GT',
#   'HN',
#   'HK',
#   'HU',
#   'IS',
#   'IE',
#   'IT',
#   'LV',
#   'LT',
#   'LU',
#   'MY',
#   'MT',
#   'MX',
#   'NL',
#   'NZ',
#   'NI',
#   'NO',
#   'PA',
#   'PY',
#   'PE',
#   'PH',
#   'PL',
#   'PT',
#   'SG',
#   'SK',
#   'ES',
#   'SE',
#   'CH',
#   'TW',
#   'TR',
#   'UY',
#   'US',
#   'GB',
#   'AD',
#   'LI',
#   'MC',
#   'ID',
#   'JP',
#   'TH',
#   'VN',
#   'RO',
#   'IL',
#   'ZA',
#   'SA',
#   'AE',
#   'BH',
#   'QA',
#   'OM',
#   'KW',
#   'EG',
#   'MA',
#   'DZ',
#   'TN',
#   'LB',
#   'JO',
#   'PS',
#   'IN',
#   'KZ',
#   'MD',
#   'UA',
#   'AL',
#   'BA',
#   'HR',
#   'ME',
#   'MK',
#   'RS',
#   'SI',
#   'KR',
#   'BD',
#   'PK',
#   'LK',
#   'GH',
#   'KE',
# ...

# %%
data['items'][0]['track']['album']['id']
# Out:
# '5JjnoGJyOxfSZUZtk2rRwZ'

# %%
data['items'][0]['track']['album']
# Out:
# {'available_markets': ['AR',
#   'AU',
#   'AT',
#   'BE',
#   'BO',
#   'BR',
#   'BG',
#   'CA',
#   'CL',
#   'CO',
#   'CR',
#   'CY',
#   'CZ',
#   'DK',
#   'DO',
#   'DE',
#   'EC',
#   'EE',
#   'SV',
#   'FI',
#   'FR',
#   'GR',
#   'GT',
#   'HN',
#   'HK',
#   'HU',
#   'IS',
#   'IE',
#   'IT',
#   'LV',
#   'LT',
#   'LU',
#   'MY',
#   'MT',
#   'MX',
#   'NL',
#   'NZ',
#   'NI',
#   'NO',
#   'PA',
#   'PY',
#   'PE',
#   'PH',
#   'PL',
#   'PT',
#   'SG',
#   'SK',
#   'ES',
#   'SE',
#   'CH',
#   'TW',
#   'TR',
#   'UY',
#   'US',
#   'GB',
#   'AD',
#   'LI',
#   'MC',
#   'ID',
#   'JP',
#   'TH',
#   'VN',
#   'RO',
#   'IL',
#   'ZA',
#   'SA',
#   'AE',
#   'BH',
#   'QA',
#   'OM',
#   'KW',
#   'EG',
#   'MA',
#   'DZ',
#   'TN',
#   'LB',
#   'JO',
#   'PS',
#   'IN',
#   'KZ',
#   'MD',
#   'UA',
#   'AL',
#   'BA',
#   'HR',
#   'ME',
#   'MK',
#   'RS',
#   'SI',
#   'KR',
#   'BD',
#   'PK',
#   'LK',
#   'GH',
#   'KE',
#   'NG',
#   'TZ',
# ...

# %%
playlist_URI = '5TZkls9cEOzWDR6qCxwDot'

# %%
data['items'][0]['track']['album']['name']
# Out:
# 'Not Like Us'

# %%
data['items'][0]['track']['album']['external_urls']['spotify']
# Out:
# 'https://open.spotify.com/album/5JjnoGJyOxfSZUZtk2rRwZ'

# %%
data['items'][0]['track']['artists'][0]['name']
# Out:
# 'Kendrick Lamar'

# %%
data['items'][0]['track']['name']
# Out:
# 'Not Like Us'

# %%
for row in data['items']:
    album_id = row['track']['album']['id']
    album_name = row['track']['album']['name']
    album_url = row['track']['album']['external_urls']['spotify']
    artist_name = row['track']['artists'][0]['name']
    song_name = row['track']['name']
    album_elements = {'album_id' : album_id,'album_name' : album_name,'album_url' : album_url,'artist_name' : artist_name,'song_name' :song_name}
    print(album_elements)
# Out:
# {'album_id': '5JjnoGJyOxfSZUZtk2rRwZ', 'album_name': 'Not Like Us', 'album_url': 'https://open.spotify.com/album/5JjnoGJyOxfSZUZtk2rRwZ', 'artist_name': 'Kendrick Lamar', 'song_name': 'Not Like Us'}
# {'album_id': '0fSfkmx0tdPqFYkJuNX74a', 'album_name': 'MUSIC', 'album_url': 'https://open.spotify.com/album/0fSfkmx0tdPqFYkJuNX74a', 'artist_name': 'Playboi Carti', 'song_name': 'EVIL J0RDAN'}
# {'album_id': '0hvT3yIEysuuvkK73vgdcW', 'album_name': 'GNX', 'album_url': 'https://open.spotify.com/album/0hvT3yIEysuuvkK73vgdcW', 'artist_name': 'Kendrick Lamar', 'song_name': 'tv off (feat. lefty gunplay)'}
# {'album_id': '5HAxzyUfyay8NElNaehsNe', 'album_name': '4X4', 'album_url': 'https://open.spotify.com/album/5HAxzyUfyay8NElNaehsNe', 'artist_name': 'Travis Scott', 'song_name': '4X4'}
# {'album_id': '0CLqdKIh14TmKqLZCs9dml', 'album_name': 'DOPAMINE', 'album_url': 'https://open.spotify.com/album/0CLqdKIh14TmKqLZCs9dml', 'artist_name': 'Lil Tecca', 'song_name': 'Half The Plot'}
# ...

# %%
album_list = []
for row in data['items']:
    album_id = row['track']['album']['id']
    album_name = row['track']['album']['name']
    album_url = row['track']['album']['external_urls']['spotify']
    artist_name = row['track']['artists'][0]['name']
    song_name = row['track']['name']
    album_elements = {'album_id' : album_id,'album_name' : album_name,'album_url' : album_url,'artist_name' : artist_name,'song_name' :song_name}
    print(album_elements)
    album_list.append(album_elements)
# Out:
# {'album_id': '5JjnoGJyOxfSZUZtk2rRwZ', 'album_name': 'Not Like Us', 'album_url': 'https://open.spotify.com/album/5JjnoGJyOxfSZUZtk2rRwZ', 'artist_name': 'Kendrick Lamar', 'song_name': 'Not Like Us'}
# {'album_id': '0fSfkmx0tdPqFYkJuNX74a', 'album_name': 'MUSIC', 'album_url': 'https://open.spotify.com/album/0fSfkmx0tdPqFYkJuNX74a', 'artist_name': 'Playboi Carti', 'song_name': 'EVIL J0RDAN'}
# {'album_id': '0hvT3yIEysuuvkK73vgdcW', 'album_name': 'GNX', 'album_url': 'https://open.spotify.com/album/0hvT3yIEysuuvkK73vgdcW', 'artist_name': 'Kendrick Lamar', 'song_name': 'tv off (feat. lefty gunplay)'}
# {'album_id': '5HAxzyUfyay8NElNaehsNe', 'album_name': '4X4', 'album_url': 'https://open.spotify.com/album/5HAxzyUfyay8NElNaehsNe', 'artist_name': 'Travis Scott', 'song_name': '4X4'}
# {'album_id': '0CLqdKIh14TmKqLZCs9dml', 'album_name': 'DOPAMINE', 'album_url': 'https://open.spotify.com/album/0CLqdKIh14TmKqLZCs9dml', 'artist_name': 'Lil Tecca', 'song_name': 'Half The Plot'}
# ...

# %%
album_list
# Out:
# [{'album_id': '5JjnoGJyOxfSZUZtk2rRwZ',
#   'album_name': 'Not Like Us',
#   'album_url': 'https://open.spotify.com/album/5JjnoGJyOxfSZUZtk2rRwZ',
#   'artist_name': 'Kendrick Lamar',
#   'song_name': 'Not Like Us'},
#  {'album_id': '0fSfkmx0tdPqFYkJuNX74a',
#   'album_name': 'MUSIC',
#   'album_url': 'https://open.spotify.com/album/0fSfkmx0tdPqFYkJuNX74a',
#   'artist_name': 'Playboi Carti',
#   'song_name': 'EVIL J0RDAN'},
#  {'album_id': '0hvT3yIEysuuvkK73vgdcW',
#   'album_name': 'GNX',
#   'album_url': 'https://open.spotify.com/album/0hvT3yIEysuuvkK73vgdcW',
#   'artist_name': 'Kendrick Lamar',
#   'song_name': 'tv off (feat. lefty gunplay)'},
#  {'album_id': '5HAxzyUfyay8NElNaehsNe',
#   'album_name': '4X4',
#   'album_url': 'https://open.spotify.com/album/5HAxzyUfyay8NElNaehsNe',
#   'artist_name': 'Travis Scott',
#   'song_name': '4X4'},
#  {'album_id': '0CLqdKIh14TmKqLZCs9dml',
#   'album_name': 'DOPAMINE',
# ...

# %%
artist_list = []
for row in data['items']:
    artist_id = row['track']['artists'][0]['id']
    artist_name = row['track']['artists'][0]['name']
    artist_url = row['track']['artists'][0]['external_urls']['spotify']
    artist_elements = {'artist_id' :artist_id,'artist_name' :artist_name,'artist_url' :artist_url}
    artist_list.append(artist_elements)

# %%
song_list = []
for row in data['items']:
    song_id = row['track']['id']
    song_name = row['track']['name']
    song_url = row['track']['external_urls']['spotify']
    song_duration = row['track']['duration_ms']
    song_added = row['added_at']
    artist_name = row['track']['artists'][0]['name']
    song_elements = {'song_id' :song_id,'song_name' :song_name,'song_url' :song_url,'song_duration' :song_duration,'song_added' :song_added,'artist_name' :artist_name}
    song_list.append(song_elements)

# %%
song_list
# Out:
# [{'song_id': '6AI3ezQ4o3HUoP6Dhudph3',
#   'song_name': 'Not Like Us',
#   'song_url': 'https://open.spotify.com/track/6AI3ezQ4o3HUoP6Dhudph3',
#   'song_duration': 274192,
#   'song_added': '2024-05-06T18:25:48Z',
#   'artist_name': 'Kendrick Lamar'},
#  {'song_id': '6iycYUk3oB0NPMdaDUrN1w',
#   'song_name': 'EVIL J0RDAN',
#   'song_url': 'https://open.spotify.com/track/6iycYUk3oB0NPMdaDUrN1w',
#   'song_duration': 183928,
#   'song_added': '2025-03-19T16:33:48Z',
#   'artist_name': 'Playboi Carti'},
#  {'song_id': '0aB0v4027ukVziUGwVGYpG',
#   'song_name': 'tv off (feat. lefty gunplay)',
#   'song_url': 'https://open.spotify.com/track/0aB0v4027ukVziUGwVGYpG',
#   'song_duration': 220690,
#   'song_added': '2024-11-29T10:33:58Z',
#   'artist_name': 'Kendrick Lamar'},
#  {'song_id': '6s8WSX1MxNThrot8ThI6fG',
#   'song_name': '4X4',
#   'song_url': 'https://open.spotify.com/track/6s8WSX1MxNThrot8ThI6fG',
#   'song_duration': 190581,
#   'song_added': '2025-01-24T12:02:14Z',
# ...

# %%
album_df = pd.DataFrame.from_dict(album_list)

# %%
for row in data['items']:
    album_id = row['track']['album']['id']
    album_name = row['track']['album']['name']
    album_url = row['track']['album']['external_urls']['spotify']
    artist_name = row['track']['artists'][0]['name']
    song_name = row['track']['name']
    print(album_name)
# Out:
# Not Like Us
# MUSIC
# GNX
# 4X4
# DOPAMINE
# GNX
# WE DON'T TRUST YOU
# Won't Stop
# GNX
# One of Wun
# GBP (feat. 21 Savage)
# PREZZI
# MUSIC
# BAND4BAND (feat. Lil Baby)
# MUSIC
# Legends (with Lil Baby)
# WE DON'T TRUST YOU
# Gaslight
# Big Dawgs
# Swing My Way
# $ome $exy $ongs 4 U
# Trending Topic
# UTOPIA
# american dream
# ALL RED
# CHROMAKOPIA
# GNX
# THE VOICEMAIL
# 100 GIGS
# MIXTAPE PLUTO
# a Gift & a Curse
# Uhh Freestyle
# euphoria
# The Death of Slim Shady (Coup De Grâce)
# Honestly, Nevermind
# HIGHEST IN THE ROOM
# Push Ups
# Tha Carter VI
# No Face
# CAN'T RUSH GREATNESS
# Drip Check
# Houdini
# Fade Me
# meet the grahams
# Purple Sky
# WHAM (Extended Version)
# The Death of Slim Shady (Coup De Grâce)
# The Plan
# WHAM
# Birds In The Trap Sing McKnight
# Family Matters
# The Forever Story (Extended Version)
# Dawgs
# DAYS BEFORE RODEO
# WHAM (Extended Version)
# VULTURES 2
# Van Cleef
# Goodbye & Good Riddance
# SAVAGE MODE II
# Headshot
# HARDSTONE PSYCHO
# ...

# %%
album_df.head(10)
# Out:
#                  album_id          album_name  \
# 0  5JjnoGJyOxfSZUZtk2rRwZ         Not Like Us
# 1  0fSfkmx0tdPqFYkJuNX74a               MUSIC
# 2  0hvT3yIEysuuvkK73vgdcW                 GNX
# 3  5HAxzyUfyay8NElNaehsNe                 4X4
# 4  0CLqdKIh14TmKqLZCs9dml            DOPAMINE
# 5  0hvT3yIEysuuvkK73vgdcW                 GNX
# 6  4iqbFIdGOTzXeDtt9owjQn  WE DON'T TRUST YOU
# 7  1TRulQDa3GYTurukQ91HGB          Won't Stop
# 8  0hvT3yIEysuuvkK73vgdcW                 GNX
# 9  7g0PJ7VbsOkYTECUFkyNPN          One of Wun
#
#                                            album_url     artist_name  \
# 0  https://open.spotify.com/album/5JjnoGJyOxfSZUZ...  Kendrick Lamar
# 1  https://open.spotify.com/album/0fSfkmx0tdPqFYk...   Playboi Carti
# 2  https://open.spotify.com/album/0hvT3yIEysuuvkK...  Kendrick Lamar
# 3  https://open.spotify.com/album/5HAxzyUfyay8NEl...    Travis Scott
# 4  https://open.spotify.com/album/0CLqdKIh14TmKqL...       Lil Tecca
# ...

# %%
album_df = album_df.drop_duplicates(subset=['album_id'])

# %%
song_df = pd.DataFrame.from_dict(song_list)

# %%
song_df.head(10)
# Out:
#                   song_id                     song_name  \
# 0  6AI3ezQ4o3HUoP6Dhudph3                   Not Like Us
# 1  6iycYUk3oB0NPMdaDUrN1w                   EVIL J0RDAN
# 2  0aB0v4027ukVziUGwVGYpG  tv off (feat. lefty gunplay)
# 3  6s8WSX1MxNThrot8ThI6fG                           4X4
# 4  3zAWhIscp6ehzXv3KHorwb                 Half The Plot
# 5  0nj9Bq5sHDiTxSHunhgkFb                   squabble up
# 6  2tudvzsrR56uom6smgOcSf                     Like That
# 7  4ugKUZExbqbkKXEmbTrTRW                    Won't Stop
# 8  2Uts1QFB4u2YNIMiqcb4de      peekaboo (feat. azchike)
# 9  4Na2HfNSr58chvfX69fy36                    one of wun
#
#                                             song_url  song_duration  \
# 0  https://open.spotify.com/track/6AI3ezQ4o3HUoP6...         274192
# 1  https://open.spotify.com/track/6iycYUk3oB0NPMd...         183928
# 2  https://open.spotify.com/track/0aB0v4027ukVziU...         220690
# 3  https://open.spotify.com/track/6s8WSX1MxNThrot...         190581
# ...

# %%
song_df = song_df.drop_duplicates(subset=['song_id'])

# %%
song_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   song_id        100 non-null    object
#  1   song_name      100 non-null    object
#  2   song_url       100 non-null    object
#  3   song_duration  100 non-null    int64
#  4   song_added     100 non-null    object
#  5   artist_name    100 non-null    object
# dtypes: int64(1), object(5)
# memory usage: 4.8+ KB

# %%
song_df['song_added'] = pd.to_datetime(song_df['song_added'])

# %%
song_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   song_id               100 non-null    object
#  1   song_name             100 non-null    object
#  2   song_url              100 non-null    object
#  3   song_duration         100 non-null    int64
#  4   song_added            100 non-null    datetime64[ns, UTC]
#  5   artist_name           100 non-null    object
#  6   2025-05-07T14:58:53Z  100 non-null    datetime64[ns, UTC]
# dtypes: datetime64[ns, UTC](2), int64(1), object(4)
# memory usage: 5.6+ KB

# %%
song_df.head(10)
# Out:
#                   song_id                     song_name  \
# 0  6AI3ezQ4o3HUoP6Dhudph3                   Not Like Us
# 1  6iycYUk3oB0NPMdaDUrN1w                   EVIL J0RDAN
# 2  0aB0v4027ukVziUGwVGYpG  tv off (feat. lefty gunplay)
# 3  6s8WSX1MxNThrot8ThI6fG                           4X4
# 4  3zAWhIscp6ehzXv3KHorwb                 Half The Plot
# 5  0nj9Bq5sHDiTxSHunhgkFb                   squabble up
# 6  2tudvzsrR56uom6smgOcSf                     Like That
# 7  4ugKUZExbqbkKXEmbTrTRW                    Won't Stop
# 8  2Uts1QFB4u2YNIMiqcb4de      peekaboo (feat. azchike)
# 9  4Na2HfNSr58chvfX69fy36                    one of wun
#
#                                             song_url  song_duration  \
# 0  https://open.spotify.com/track/6AI3ezQ4o3HUoP6...         274192
# 1  https://open.spotify.com/track/6iycYUk3oB0NPMd...         183928
# 2  https://open.spotify.com/track/0aB0v4027ukVziU...         220690
# 3  https://open.spotify.com/track/6s8WSX1MxNThrot...         190581
# ...

# %%
song_df= song_df.drop('2025-05-07T14:58:53Z',axis=1)

# %%
song_df.head()
# Out:
#                   song_id                     song_name  \
# 0  6AI3ezQ4o3HUoP6Dhudph3                   Not Like Us
# 1  6iycYUk3oB0NPMdaDUrN1w                   EVIL J0RDAN
# 2  0aB0v4027ukVziUGwVGYpG  tv off (feat. lefty gunplay)
# 3  6s8WSX1MxNThrot8ThI6fG                           4X4
# 4  3zAWhIscp6ehzXv3KHorwb                 Half The Plot
#
#                                             song_url  song_duration  \
# 0  https://open.spotify.com/track/6AI3ezQ4o3HUoP6...         274192
# 1  https://open.spotify.com/track/6iycYUk3oB0NPMd...         183928
# 2  https://open.spotify.com/track/0aB0v4027ukVziU...         220690
# 3  https://open.spotify.com/track/6s8WSX1MxNThrot...         190581
# 4  https://open.spotify.com/track/3zAWhIscp6ehzXv...         165937
#
#                  song_added     artist_name
# 0 2024-05-06 18:25:48+00:00  Kendrick Lamar
# 1 2025-03-19 16:33:48+00:00   Playboi Carti
# 2 2024-11-29 10:33:58+00:00  Kendrick Lamar
# ...

# %%
artist_list
# Out:
# [{'artist_id': '2YZyLoL8N0Wb9xBt1NhZWg',
#   'artist_name': 'Kendrick Lamar',
#   'artist_url': 'https://open.spotify.com/artist/2YZyLoL8N0Wb9xBt1NhZWg'},
#  {'artist_id': '699OTQXzgjhIYAHMy9RyPD',
#   'artist_name': 'Playboi Carti',
#   'artist_url': 'https://open.spotify.com/artist/699OTQXzgjhIYAHMy9RyPD'},
#  {'artist_id': '2YZyLoL8N0Wb9xBt1NhZWg',
#   'artist_name': 'Kendrick Lamar',
#   'artist_url': 'https://open.spotify.com/artist/2YZyLoL8N0Wb9xBt1NhZWg'},
#  {'artist_id': '0Y5tJX1MQlPlqiwlOH1tJY',
#   'artist_name': 'Travis Scott',
#   'artist_url': 'https://open.spotify.com/artist/0Y5tJX1MQlPlqiwlOH1tJY'},
#  {'artist_id': '4Ga1P7PMIsmqEZqhYZQgDo',
#   'artist_name': 'Lil Tecca',
#   'artist_url': 'https://open.spotify.com/artist/4Ga1P7PMIsmqEZqhYZQgDo'},
#  {'artist_id': '2YZyLoL8N0Wb9xBt1NhZWg',
#   'artist_name': 'Kendrick Lamar',
#   'artist_url': 'https://open.spotify.com/artist/2YZyLoL8N0Wb9xBt1NhZWg'},
#  {'artist_id': '1RyvyyTE3xzB2ZywiAwp0i',
# ...

# %%
artist_df = pd.DataFrame.from_dict(artist_list)

# %%
artist_df.head(10)
# Out:
#                 artist_id     artist_name  \
# 0  2YZyLoL8N0Wb9xBt1NhZWg  Kendrick Lamar
# 1  699OTQXzgjhIYAHMy9RyPD   Playboi Carti
# 2  2YZyLoL8N0Wb9xBt1NhZWg  Kendrick Lamar
# 3  0Y5tJX1MQlPlqiwlOH1tJY    Travis Scott
# 4  4Ga1P7PMIsmqEZqhYZQgDo       Lil Tecca
# 5  2YZyLoL8N0Wb9xBt1NhZWg  Kendrick Lamar
# 6  1RyvyyTE3xzB2ZywiAwp0i          Future
# 7  2hlmm7s2ICUX0LVIhVFlZQ           Gunna
# 8  2YZyLoL8N0Wb9xBt1NhZWg  Kendrick Lamar
# 9  2hlmm7s2ICUX0LVIhVFlZQ           Gunna
#
#                                           artist_url
# 0  https://open.spotify.com/artist/2YZyLoL8N0Wb9x...
# 1  https://open.spotify.com/artist/699OTQXzgjhIYA...
# 2  https://open.spotify.com/artist/2YZyLoL8N0Wb9x...
# 3  https://open.spotify.com/artist/0Y5tJX1MQlPlqi...
# 4  https://open.spotify.com/artist/4Ga1P7PMIsmqEZ...
# 5  https://open.spotify.com/artist/2YZyLoL8N0Wb9x...
# 6  https://open.spotify.com/artist/1RyvyyTE3xzB2Z...
# 7  https://open.spotify.com/artist/2hlmm7s2ICUX0L...
# ...

# %%
artist_df = artist_df.drop_duplicates(subset=['artist_id'])

# %%
artist_df.head(5)
# Out:
#                 artist_id     artist_name  \
# 0  2YZyLoL8N0Wb9xBt1NhZWg  Kendrick Lamar
# 1  699OTQXzgjhIYAHMy9RyPD   Playboi Carti
# 3  0Y5tJX1MQlPlqiwlOH1tJY    Travis Scott
# 4  4Ga1P7PMIsmqEZqhYZQgDo       Lil Tecca
# 6  1RyvyyTE3xzB2ZywiAwp0i          Future
#
#                                           artist_url
# 0  https://open.spotify.com/artist/2YZyLoL8N0Wb9x...
# 1  https://open.spotify.com/artist/699OTQXzgjhIYA...
# 3  https://open.spotify.com/artist/0Y5tJX1MQlPlqi...
# 4  https://open.spotify.com/artist/4Ga1P7PMIsmqEZ...
# 6  https://open.spotify.com/artist/1RyvyyTE3xzB2Z...
